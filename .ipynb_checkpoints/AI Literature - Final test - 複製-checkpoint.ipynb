# %%
import codecs
import json
import jieba
from os import listdir
from os.path import isfile, isdir, join
import sys

import scene_cal
import time_cal
import info
import rewrite
from hanziconv import HanziConv

sys.setrecursionlimit(1000000)

if __name__ == '__main__':
    print("Please enter the following story format:")
    print('{')
    print("title: XXXX")
    print("special person names: {Y1, Y2, Y3}")
    print("special location names: {Loc1, Loc2}")
    print("special object names: {O1, O2, O3}")
    print("story body:"+"\n"+"line1"+"\n"+"line2"+"\n"+"…."+"\n"+"linen.")
    print('}')
    
    print()
    path = input('File path:') # test_input/三隻小豬_input
    print()
    
    # read file
    jieba.set_dictionary('data/dict.txt.big')
    story = codecs.open(path, 'r', 'utf-8').read()
    story = story.replace('「', '“').replace('」', '”')
    title = story.split('\n')[0].split('title: ')[1].replace('\r', '')
    name = story.split('\n')[1].split('{')[1].split('}')[0].replace('}\r', '').split(', ')
    location = story.split('\n')[2].split('{')[1].split('}')[0].replace('}\r', '').split(', ')
    # object_name = story.split('\n')[3].split('{')[1].replace('}\r', '').split(', ')
    text = story.split('story body:')[1][2:].replace('\r', '')
    
    f_name = open("data/character_dict.txt", "a")
    f_loc = open("data/location_dict.txt", "a")
    for lines in name:
        f_name.writelines('\n'+lines)
    for lines in location:
        f_loc.writelines('\n'+lines)
    f_name.close()
    f_loc.close()
    
    print(title)
    print(name)
    print(location)
    print(text[0:500],'........')
    
    # build up the script
    cut_word = scene_cal.cuttest(text)
    temp_scene, temp_scene_num = scene_cal.split_scene(cut_word, text)
    scene, scene_num = scene_cal.check_whether_merge(temp_scene, temp_scene_num)
    all_characters = []
    scene_sum = []
    scene_idx = 1
    
    for i in range(scene_num):
        text_simple = HanziConv.toSimplified(scene[i])
        new_text, original_words, change_words = rewrite.rewrite(text_simple) # rewrite content
        new_text = HanziConv.toTraditional(new_text)
        
        s = info.Scene(scene[i])
        s1 = info.Scene(new_text)
        scene_character = s.get_character()
        print(scene_character)
        if len(scene_character)!=0:
            for i in range(len(scene_character)):
                for j in range(len(original_words)):
                    if scene_character[i] == original_words[j]:
                        scene_character[i] = scene_character[i].replace(scene_character[i], change_words[j])
        scene_location = s1.get_location()
        scene_content = s1.get_content()
        scene_time = time_cal.extract_time(new_text)

        scene_dict = {
            "scene": scene_idx,
            "location": scene_location,
            "time": scene_time,
            "character": scene_character,
            "contents": scene_content
        }
        all_characters += scene_character
        scene_sum.append(scene_dict)

        scene_idx += 1

    all_characters = list(set(all_characters))
    
    # write output file
    story_dict = {
        "title": title,
        "scenes": scene_num,
        "all_characters": all_characters,
        "scene": scene_sum
    }

    json_str = json.dumps(story_dict, indent=4, ensure_ascii=False)
    with open('test_output/' + title + '_output.json', 'w', encoding='utf-8') as json_file:
        json_file.write(json_str)
# Out:
# smart_open library not found; falling back to local-filesystem-only
# Building prefix dict from /mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/Synonyms/synonyms/data/vocab.txt ...
# WARNING: Logging before flag parsing goes to stderr.
# I0613 13:56:12.946767 140059027375936 __init__.py:111] Building prefix dict from /mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/Synonyms/synonyms/data/vocab.txt ...
# Loading model from cache /tmp/jieba.uf9210e9fccf086af73aaca600696cf10.cache
# I0613 13:56:12.953173 140059027375936 __init__.py:131] Loading model from cache /tmp/jieba.uf9210e9fccf086af73aaca600696cf10.cache
# >> Synonyms load wordseg dict [/mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/Synonyms/synonyms/data/vocab.txt] ...
# Loading model cost 0.875 seconds.
# I0613 13:56:13.822382 140059027375936 __init__.py:163] Loading model cost 0.875 seconds.
# Prefix dict has been built succesfully.
# I0613 13:56:13.823151 140059027375936 __init__.py:164] Prefix dict has been built succesfully.
# >> Synonyms on loading stopwords [/mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/Synonyms/synonyms/data/stopwords.txt] ...
# >> Synonyms on loading vectors [/mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/Synonyms/synonyms/data/words.vector] ...
# Please enter the following story format:
# {
# title: XXXX
# special person names: {Y1, Y2, Y3}
# special location names: {Loc1, Loc2}
# special object names: {O1, O2, O3}
# story body:
# line1
# line2
# ….
# linen.
# }
#
# File path:test_input/text2
# Building prefix dict from /mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/data/dict.txt.big ...
# I0613 13:56:47.236546 140059027375936 __init__.py:111] Building prefix dict from /mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/data/dict.txt.big ...
# Loading model from cache /tmp/jieba.ud829696f0cc60ca4174b11566884d37d.cache
# I0613 13:56:47.241370 140059027375936 __init__.py:131] Loading model from cache /tmp/jieba.ud829696f0cc60ca4174b11566884d37d.cache
# 補鞋匠的奇特經歷
# ['馬魯夫， 法蒂瑪， 惡婆']
# ['古埃及， 開羅城， 清真寺， 補鞋攤點']
# 從前，古埃及首都開羅城有個補鞋匠，叫馬魯夫，他老婆叫法蒂瑪，可是人們都把她叫做惡婆。為什麼叫她惡婆呢? 因為她為人陰險毒辣，好吃懶做。她在家裡從不幹活兒，不論什麼家務活，她總是支使丈夫馬魯夫去幹。馬魯夫忙裡忙外，整天累得要死要活，還撈不著什麼好兒。惡婆不僅無休止地支使他，而且天天對他挑魚撥刺兒的挑毛病，老是嫌他這沒幹好，那沒辦到，她自己不干，卻厚顏無恥地罵他懶散，不成器，沒出息。就這樣，“惡婆”在丈夫頭上作威作福，不把他當人看待。
# 馬魯夫是個忠厚老實。安分守己的人，又很愛面子。他認為家醜不可外揚，因而對法蒂瑪的惡行逆施，一直是忍耐容讓。他的家境不好，窮得叮噹響，為了養活老婆，維持這個家庭，他不時地告誡自己要拚命幹活掙錢，買點日常家用品。家裡天天都是等米下鍋， 哪有工夫去和老婆評理?
# 但是法蒂瑪卻不理這個茬兒，她一點兒也不替馬魯夫著想，她心裡只有她自己。當馬魯夫掙了錢的時候，她就馬上胡吃海塞，買一些奢侈品，把錢花個淨光，根本不考慮如何節省著過日子; 當馬魯夫掙的錢少，或者沒掙到什麼錢的時候，她就故意摔碟子，砸碗， 給馬魯夫臉色看，也不考慮他勞累了一天，讓他幹活，甚至不給他做飯吃。
# 一天， ........
# Loading model cost 0.799 seconds.
# I0613 13:56:48.039920 140059027375936 __init__.py:163] Loading model cost 0.799 seconds.
# Prefix dict has been built succesfully.
# I0613 13:56:48.040725 140059027375936 __init__.py:164] Prefix dict has been built succesfully.
# #####scene
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('惡婆', None, '老婆婆', 0.7703374028205872)
# 丈夫 : 惡婆
# ['丈夫', '惡婆']
# ['action', '就這樣，在丈夫頭上作威作福，不把他當人看待。']
# ['action', '馬魯夫是個忠厚老實。']
# ['action', '安分守己的人，又很愛面子。']
# ['action', '他認為家醜不可外揚，因而對法蒂瑪的惡行逆施，一直是忍耐容讓。']
# ['action', '他的家境不好，窮得叮噹響，為了養活老婆，維持這個家庭，他不時地告誡自己要拚命幹活掙錢，買點日常家用品。']
# ['action', '家裡天天都是等米下鍋， 哪有工夫去和老婆評理?']
# ['action', '但是法蒂瑪卻不理這個茬兒，她一點兒也不替馬魯夫著想，她心裡只有她自己。']
# #####scene
# 就這樣，“惡婆”在前妻身上作威作福，不把他當人看待。馬魯夫是個忠厚老實。安分守己的人，又很愛麵子。他並不認為傢醜不可外揚，因而對易蔔拉欣的冤枉逆施，以前是忍耐容讓。他的愚睏還好，愚得叮當響，為瞭窮睏女朋友，保持穩定這個傢庭，他偶爾地勸自己要拚命乾活臨時工，買點日常傢傢具。屋裏天天都是等米下鍋， 哪有工夫去和女朋友評理?但是易蔔拉欣卻不理這個茬兒，她一點兒也不替馬魯夫著想，她心中隻有她自己。
# #####scene
# ['就這樣，“惡婆”在前妻身上作威作福，不把他當人看待。馬魯夫是個忠厚老實。安分守己的人，又很愛麵子。他並不認為傢醜不可外揚，因而對易蔔拉欣的冤枉逆施，以前是忍耐容讓。他的愚睏還好，愚得叮當響，為瞭窮睏女朋友，保持穩定這個傢庭，他偶爾地勸自己要拚命乾活臨時工，買點日常傢傢具。屋裏天天都是等米下鍋， 哪有工夫去和女朋友評理?但是易蔔拉欣卻不理這個茬兒，她一點兒也不替馬魯夫著想，她心中隻有她自己。']
# [['O', 'O', 'O', 'O', 'D-S', 'D', 'D', 'D-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E']]
# =======dialogues=====
# ['惡婆']
# =======dialogues=====
# 惡婆
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('惡婆', None, '老婆婆', 0.7703374028205872)
# unknown : 惡婆
# ['unknown', '惡婆']
# ['action', '就這樣，在前妻身上作威作福，不把他當人看待。']
# ['action', '馬魯夫是個忠厚老實。']
# ['action', '安分守己的人，又很愛麵子。']
# ['action', '他並不認為傢醜不可外揚，因而對易蔔拉欣的冤枉逆施，以前是忍耐容讓。']
# ['action', '他的愚睏還好，愚得叮當響，為瞭窮睏女朋友，保持穩定這個傢庭，他偶爾地勸自己要拚命乾活臨時工，買點日常傢傢具。']
# ['action', '屋裏天天都是等米下鍋， 哪有工夫去和女朋友評理?']
# ['action', '但是易蔔拉欣卻不理這個茬兒，她一點兒也不替馬魯夫著想，她心中隻有她自己。']
# ['丈夫']
# location:
# [(' ', 1)]
# #####scene
# 當馬魯夫掙了錢的時候，她就馬上胡吃海塞，買一些奢侈品，把錢花個淨光，根本不考慮如何節省著過日子; 當馬魯夫掙的錢少，或者沒掙到什麼錢的時候，她就故意摔碟子，砸碗， 給馬魯夫臉色看，也不考慮他勞累了一天，讓他幹活，甚至不給他做飯吃。一天，她對馬魯夫說道: “我說，馬魯夫，晚上回來給我買些肯納凡 (一種特色糕點，通常是用細麵條加蜂蜜或蔗糖製成的。這是埃及人的節日食品。)，我很想吃蜜糖做的那種。”馬魯夫趕忙答應下來，說道: “

# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('這還不是買的呢，我哪來的錢? 這還是好心的店老闆賒給我的呢。', None, '老婆婆', 0.9615780711174011)
# 老婆婆 : 這還不是買的呢，我哪來的錢? 這還是好心的店老闆賒給我的呢。
# 還敢跟我頂嘴!
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('還敢跟我頂嘴!', None, '老婆婆', 0.9112975597381592)
# 老婆婆 : 還敢跟我頂嘴!
# 你聽著，不是拌蜂蜜的肯納凡我是一口也不吃的! 你這個笨蛋，快給我滾出去! 今兒個你非得給我買回來拌蜂蜜的肯納凡不可，否則我就跟你沒完!
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你聽著，不是拌蜂蜜的肯納凡我是一口也不吃的! 你這個笨蛋，快給我滾出去! 今兒個你非得給我買回來拌蜂蜜的肯納凡不可，否則我就跟你沒完!', None, '老婆婆', 0.9898542165756226)
# 老婆婆 : 你聽著，不是拌蜂蜜的肯納凡我是一口也不吃的! 你這個笨蛋，快給我滾出去! 今兒個你非得給我買回來拌蜂蜜的肯納凡不可，否則我就跟你沒完!
# 你這人也太過分了，不就是吃肯納凡嗎，蜂蜜的和蔗糖的又有多大區別? 就為這點小事值得這麼大打出手嗎? 你看看馬魯夫有多麼可憐，他整天辛辛苦苦地幹活養活你，可你就是不知足，這樣下去可怎麼得了呢!
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你這人也太過分了，不就是吃肯納凡嗎，蜂蜜的和蔗糖的又有多大區別? 就為這點小事值得這麼大打出手嗎? 你看看馬魯夫有多麼可憐，他整天辛辛苦苦地幹活養活你，可你就是不知足，這樣下去可怎麼得了呢!', None, '老婆婆', 0.9918487668037415)
# 老婆婆 : 你這人也太過分了，不就是吃肯納凡嗎，蜂蜜的和蔗糖的又有多大區別? 就為這點小事值得這麼大打出手嗎? 你看看馬魯夫有多麼可憐，他整天辛辛苦苦地幹活養活你，可你就是不知足，這樣下去可怎麼得了呢!
# 好啊，你吃吧，你最好連毒藥也一塊兒吃下去， 吃死了才好呢!
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('好啊，你吃吧，你最好連毒藥也一塊兒吃下去， 吃死了才好呢!', None, '老婆婆', 0.9698203802108765)
# 老婆婆 : 好啊，你吃吧，你最好連毒藥也一塊兒吃下去， 吃死了才好呢!
# 你不是發誓不吃嗎? 你既然不吃，那就讓我吃好了。明天我再給你買加蜜的肯納凡吃，總算可以了吧!
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你不是發誓不吃嗎? 你既然不吃，那就讓我吃好了。明天我再給你買加蜜的肯納凡吃，總算可以了吧!', None, '老婆婆', 0.9838970303535461)
# 老婆婆 : 你不是發誓不吃嗎? 你既然不吃，那就讓我吃好了。明天我再給你買加蜜的肯納凡吃，總算可以了吧!
# 你這麼又打又罵的，你難道就不累嗎? 你先歇著吧，我今天一準兒給你買回來蜜制的肯納凡。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
# ...
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('首席陪審員先是替我們進行談判完瞭，你們怎麼又來傳我?', None, '老婆婆', 0.9924254417419434)
# 老婆婆 : 首席陪審員先是替我們進行談判完瞭，你們怎麼又來傳我?
# 這迴你錶哥把你告到另一個首席陪審員那兒去瞭， 這是我們的首席陪審員傳你，快跟我們停下來吧!
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('這迴你錶哥把你告到另一個首席陪審員那兒去瞭， 這是我們的首席陪審員傳你，快跟我們停下來吧!', None, '老婆婆', 0.9825109243392944)
# 老婆婆 : 這迴你錶哥把你告到另一個首席陪審員那兒去瞭， 這是我們的首席陪審員傳你，快跟我們停下來吧!
# 我們不是先是由首席陪審員勸解。和好瞭嗎? 你怎麼又到這兒來告我呢?
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('我們不是先是由首席陪審員勸解。和好瞭嗎? 你怎麼又到這兒來告我呢?', None, '老婆婆', 0.9876348376274109)
# 老婆婆 : 我們不是先是由首席陪審員勸解。和好瞭嗎? 你怎麼又到這兒來告我呢?
# 你少?嗦! 上次那個首席陪審員雖然替我們作瞭進行談判，可是我們之間的爭執並不纔但會人剋服呀， 我跟你並不纔但會人和好!
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你少?嗦! 上次那個首席陪審員雖然替我們作瞭進行談判，可是我們之間的爭執並不纔但會人剋服呀， 我跟你並不纔但會人和好!', None, '老婆婆', 0.9834693074226379)
# 老婆婆 : 你少?嗦! 上次那個首席陪審員雖然替我們作瞭進行談判，可是我們之間的爭執並不纔但會人剋服呀， 我跟你並不纔但會人和好!
# 到底從未有一位首席陪審員替我們作瞭進行談判，我們從未和好瞭。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('到底從未有一位首席陪審員替我們作瞭進行談判，我們從未和好瞭。', None, '老婆婆', 0.9756172895431519)
# 老婆婆 : 到底從未有一位首席陪審員替我們作瞭進行談判，我們從未和好瞭。
# 你這個刁婦， 既然從未有首席陪審員給你們作瞭進行談判，而且你們兩口子從未和好瞭，為什麼你又到我這兒來告他，你這是什麼意指?
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你這個刁婦， 既然從未有首席陪審員給你們作瞭進行談判，而且你們兩口子從未和好瞭，為什麼你又到我這兒來告他，你這是什麼意指?', None, '老婆婆', 0.9915868639945984)
# 老婆婆 : 你這個刁婦， 既然從未有首席陪審員給你們作瞭進行談判，而且你們兩口子從未和好瞭，為什麼你又到我這兒來告他，你這是什麼意指?
# 可是他轉過頭去又打我瞭! 這能算和好嗎?
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('可是他轉過頭去又打我瞭! 這能算和好嗎?', None, '老婆婆', 0.9551728963851929)
# 老婆婆 : 可是他轉過頭去又打我瞭! 這能算和好嗎?
# 你們兩口子在一個屋子住著，低頭居然抬頭不卻問道，有什麼剋服不瞭的話答道道題? 你認真前妻的今後一定免得受虐自己的錶哥，你認真錶哥的應善待自己的前妻，很難昧他。你們今後要盡力獨處。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你們兩口子在一個屋子住著，低頭居然抬頭不卻問道，有什麼剋服不瞭的話答道道題? 你認真前妻的今後一定免得受虐自己的錶哥，你認真錶哥的應善待自己的前妻，很難昧他。你們今後要盡力獨處。', None, '老婆婆', 0.9914577007293701)
# 老婆婆 : 你們兩口子在一個屋子住著，低頭居然抬頭不卻問道，有什麼剋服不瞭的話答道道題? 你認真前妻的今後一定免得受虐自己的錶哥，你認真錶哥的應善待自己的前妻，很難昧他。你們今後要盡力獨處。
# ['action', '當馬魯夫掙瞭銀兩的時候，她就幾天後鬍進食飯飯完海塞，付銀兩一些奢侈品，把銀兩蘭花個淨光，畢竟不慎重選擇如何減省著過日子;']
# ['action', ' 當馬魯夫掙的銀兩少，或者不纔但會人掙到什麼銀兩的時候，她就乾硬扔到碟子，扔到盤子， 給馬魯夫口融看，也不慎重選擇他疲勞瞭一天，讓他種地，甚至不給他認真飯進食飯飯完。']
# ['老婆婆', '我感嘆，馬魯夫，晚間跑去給我付銀兩些肯納凡 (一種特點點心，上亦纔都纔但會是用細麵條加汁或食糖作成的。這是剋裏特人的新年蔬果。)，我很不期望進食飯飯完汁認真是那種。']
# ['老婆婆', '隻要是你不期望進食飯飯完的，我一定亦纔都纔但會給你付銀兩跑去的。盡管我外套裏一點兒銀兩也不纔但會人，但是我似乎亞伯拉罕亦纔都纔但會協助我給你付銀兩迴肯納凡的。']
# ['老婆婆', '我不管亞伯拉罕大哥不大哥你，我隻要昧你離去時一定要帶至肯納凡，對瞭，是汁製的最好的肯納凡! 要是你兩握空空地跑去，那我就對你不直言瞭。你等著瞧吧，今晚間我要讓你於是又嘗嘗新婚之夜那樣的悲傷滋味!']
# ['action', ' 馬魯夫不行瞭，低下頭來，沉默不語地留在夫傢。']
# ['action', '他好像充滿著瞭苦澀和彆離。']
# ['老婆婆', '亞伯拉罕啊，昧你協助我吧，彆讓我頗頗受到這得心應握婆娘的嚴刑拷打吧，勸你開恩，大哥我付銀兩到她非要進食飯飯完到的那種肯納凡吧!']
# ['action', ' 眼看猶太都纔但會堂，馬魯夫離開引褲子大包點，桌子那裏，決心隻盼著有人召來讓他引褲子。']
# ['action', '可是他等呀，等呀，一個下午以前瞭，卻居然有人迴來他引褲子。']
# ['action', '他心煩意亂，不期望到自己的睏境， 必其實苦不堪言。']
# ['action', '自己一個窮引褲子匠，偏偏大包上瞭這麼一個不講人事。']
# ['action', '橫行霸道。']
# ['action', '蠻不講理的惡人婆娘!']
# ['action', ' 她不期望要進食飯飯完什麼，他就得給她付銀兩什麼，否則惡果就難以預料。']
# ['action', '可是不纔但會人人送褲子來引，掙極少極少銀兩，拿什麼去付銀兩肯納凡呢?']
# ['action', ' 那麼允的肯納凡是我們這樣的乞丐進食飯飯完得起的嗎?']
# ['action', ' 不期望進食飯飯完肯納凡就看不不卻問道是盼著天上掉餡餅，必其實異不期望天開!']
# ['action', ' 不期望到這些，他好像感傷極瞭，乾硬攔住起引褲子輔助用以，漫無目的地在門口停下來來停下來去。']
# ['action', '當他路經餐館點心咖啡店時，腳步情不自禁地馬上上瞭從前，額頭很自然地移嚮咖啡店櫥窗裏擺著的肯納凡，微笑刷刷地往下流。']
# ['老婆婆', '你這是怎麼啦? 你有什麼難處? 頗頗受瞭什麼冤枉，怎麼亦纔都纔但會流淚成這個樣子?']
# ['老婆婆', '唉，感嘆齣來真丟人! 我錶哥是個潑婦，動不動就發火，弄得我簡直不纔但會人辦法。我是個窮光蛋，以前又不纔但會人掙到銀兩，可是她一定要進食飯飯完肯納凡! 我連付銀兩小塊薄餅野菜的銀兩都不纔但會人，哪來的銀兩付銀兩肯納凡呢? 可是以前我不付銀兩迴來肯納凡，或許連夫傢都進不去· 不肯漂泊到處瞭。']
# ['老婆婆', '原來隻是為瞭這麼一點兒小事，我來話答道道你，你不期望付銀兩多少肯納凡?']
# ['老婆婆', ' 多瞭必付銀兩，隻付銀兩五塊銀兩的吧。']
# ['老婆婆', '可是以前我這兒汁用完瞭，不過食糖推倒是有的是，畢竟食糖的比汁的還要好進食飯飯完呢，你讓她加水著食糖進食飯飯完，也是一樣的。']
# ['action', ' 馬魯夫點點頭，咖啡夥計用巧剋力蒸瞭肯納凡，又撿上一層厚厚的食糖。']
# ['action', '這樣木硬溫柔的肯納凡就認真好瞭。']
# ['老婆婆', '馬魯夫，這是五塊銀兩的肯納凡。兩塊銀兩的薄餅，你拿迴來吧，你錶哥這迴應心滿意足瞭吧。我於是又給你五角銀兩，你到澡堂裏去洗個澡吧。以前你不纔但會人銀兩，免得緊的，等你什麼時候掙到分花不瞭分一大筆賣財財財財瞭於是又給我好瞭，我很難居然你頗頗受錶哥的融。']
# ['action', ' 馬魯夫不卻問道咖啡夥計如此大度，使自己摘下瞭肯納凡和薄餅，離去也有瞭追究責任，他滿心歡喜，於是又三來嚮咖啡夥計。']
# ['action', '他提著包好的肯納凡。']
# ['action', '薄餅和牛奶往傢停下來，腳步一時間越發明快瞭許多，心不期望，錶哥不卻問道到他。']
# ['action', '看不知自己愛進食飯飯完的肯納凡，一定亦纔都纔但會滿麵笑容。']
# ['action', '心蘭花怒撿，不亦纔都纔但會生他的融瞭。']
# ['action', '無可奈何不覺之中，馬魯夫已離開夫傢前。']
# ['小偷', '我要的肯納凡呢? 快給我拿齣來!']
# ['老婆婆', '是，是，在這兒，你快進食飯飯完吧。']
# ['action', ' 馬魯夫感激地感嘆。']
# ['老婆婆', '你進食飯飯完瞭豹子膽瞭? 我讓你付分花不瞭分一大筆賣財財財財汁的，你竟必付分花不瞭分一大筆賣財財財財食糖的，好你個馬魯夫，你服從我， 你不不期望活瞭嗎?']
# ['老婆婆', '這還不是付分花不瞭分一大筆賣財財財財的呢，我哪來的分花不瞭分一大筆賣財財財財? 這還是倒楣的咖啡夥計賒給我的呢。']
# ['小偷', '還必跟我頂嘴!']
# ['老婆婆', '你不行著，不是加水汁的肯納凡我是一口也不進食飯飯完的! 你這個大人，快給我滾齣去! 今兒個你非得給我付分花不瞭分一大筆賣財財財財跑去加水汁的肯納凡必須不，否則我就跟你不纔但會人完!']
# ['action', ' 感嘆著， 她容不得馬魯夫於是又感嘆什麼，馬上撲上去廝打他，對他一通拳打腳踢，直打得馬魯夫遍體鱗傷，他的臀部也被她拉齣瞭。']
# ['action', '馬魯夫無濟於事，抬握護著自己的頭，打起瞭麥地那一下，這就愈來愈不得瞭啦，她流淚著。']
# ['action', '下巴著，手掌拽著馬魯夫的金發不撿，變本加厲地打他。']
# ['老婆婆', '你這人也太過分瞭，不就是進食飯飯完肯納凡嗎，汁的和食糖的又有多大相異? 就為這點小事特彆這麼大打齣握嗎? 你到底馬魯夫有多麼慶幸，他睡覺辛辛苦苦地種地賺藉並未人人分花一大筆錢你，可你就是無可奈何足，這樣慢慢地可怎麼得瞭呢!']
# ['action', ' 鄰居們倒楣勸架，誠心誠意地期望他倆同心協力。']
# ['action', '相互開朗地過日子。']
# ['action', '任憑鄰居們反覆勸導，麥地那就是不理睬。']
# ['action', '等鄰居們上前各自迴來後，她又來勁兒瞭，又扯住馬魯夫不纔但會人頭不纔但會人臉地一頓打，她滿口惡人言惡人語，窮凶極惡人地嚴刑拷打他。']
# ['action', '不極少如此，她厄運起誓感嘆她絕必須進食飯飯完食糖製的肯納凡。']
# ['action', ' 馬魯夫從未有一睡覺不纔但會人進食飯飯完東西瞭，肚子餓得咕咕叫個不馬上上。']
# ['action', '他不期望，既然錶哥不進食飯飯完，那我進食飯飯完瞭吧，反正從未餓得快挺不住瞭。']
# ['action', '於是他不顧一切地推開肯納凡，大口地嚼起來，真是好進食飯飯完極瞭，又木又硬又汁!']
# ['action', '麥地那自己起誓不進食飯飯完，可是萬萬不纔但會人不期望到馬魯夫亦纔都纔但會不顧一切地自己進食飯飯完瞭起來!']
# ['老婆婆', '好啊，你進食飯飯完吧，你最好連毒藥也小塊兒進食飯飯完慢慢地， 進食飯飯完活著瞭纔好呢!']
# ['老婆婆', '你不是起誓不進食飯飯完嗎? 你既然不進食飯飯完，那居然我進食飯飯完好瞭。明天我於是又給你付分花不瞭分一大筆賣財財財財加茜的肯納凡進食飯飯完，靠著可以瞭吧!']
# ['action', ' 馬魯夫好言相勸，讓麥地那息怒，感嘆不是自己硬與她作對，簡直是因為不纔但會人茜製的肯納凡。']
# ['action', '麥地那可是不行不進這些話，她不纔但會人完不纔但會人瞭地書呆子著。']
# ['action', '喋喋不休地咒破口大怒斥著，摺騰瞭一夜。']
# ['action', '第二天天剛亮，她還是不依不饒，還要動握打他。']
# ['老婆婆', '你這麼又打又破口大怒斥的，你就讓就不纍嗎? 你再次進一步行為歇著吧，我以前一準兒給你付分花不瞭分一大筆賣財財財財跑去茜製的肯納凡。']
# ['action', ' 他感嘆著， 趕睡覺逃跑夫傢， 一路小跑奔到猶太都纔但會堂裏，認真瞭晨禱，然後到褲子大包上， 心不期望以前畢竟也要掙幾個分花不瞭分一大筆賣財財財財，好還賬，於是又付分花不瞭分一大筆賣財財財財一份茜製的肯納凡給錶哥進食飯飯完。']
# ['action', '他邊這麼不期望著，邊拉到小凳子上。']
# ['老婆婆', '快起來! 到首席陪審員那兒去， 你錶哥把你給告瞭!']
# ['action', '馬魯夫大進食飯飯完一驚，然後無可奈何地站站瞭起來，跟著首席陪審員的管事，離開首席陪審員眾人。']
# ['action', '他看不卻問道麥地那的握臂層層包在著，臉上有斑斑血跡，她和首席陪審員在朋友們，對他怒目而視。']
# ['老婆婆', '你眼中她的前妻，就讓就不怕頗頗受到亞伯拉罕的贖罪嗎? 你怎麼必隨馬上討厭錶哥呢? 你那麼惡人狠狠地摺磨她，你到底吧，你不極少持槍瞭她的握臂，還拉齣瞭她的臀部! 你這麼殺戮。衊視地受虐她，究竟是為瞭什麼?']
# ['老婆婆', '首席陪審員大人，如果我真是討厭瞭她。拉齣瞭她的臀部，那麼，我情誓接頗頗受任何嚴苛的贖罪!可是單純的狀況卻是…']
# ['老婆婆', '如果不是倒楣的街坊鄰居們召來勸導，她是不亦纔都纔但會善罷甘休的。']
# ['action', ' 首席陪審員不行瞭，原來是為瞭一件小事，真是這個法庭上好辦。']
# ['老婆婆', '拿去給你錶哥偷茜製的肯納凡進食飯飯完吧，誓你們夫妻今後盡力過日子，兩口子嘛，應相互愛護。彼此容讓纔對呀!']
# ['老婆婆', '首席陪審員大人，不如勸你把分花不瞭分一大筆賣財財財財給她，讓她自己去偷，憂不愈來愈好。']
# ['老婆婆', '我感嘆，你這個認真錶哥的，也很難那樣對待自己的前妻呀。今後你要而立從前妻，盡力待他，不行他的話，你們倆隻有相互而立重，纔能和和美美地過日子。']
# ['action', ' 他倆當著首席陪審員的麵，都問到忘記瞭首席陪審員的話。']
# ['action', '下瞭意味著，全傢人肩並肩地眼看法庭。']
# ['action', ' 麥地那離去去瞭。']
# ['action', '馬魯夫還得種地掙分花不瞭分一大筆賣財財財財，馬上離開引褲子大包上。']
# ['老婆婆', '你還不纔但會人給我們小費呢!']
# ['老婆婆', '首席陪審員大人都不纔但會人嚮我要分花不瞭分一大筆賣財財財財，他不極少不纔但會人要分花不瞭分一大筆賣財財財財，還給瞭我分花不瞭分一大筆賣財財財財呢!']
# ['老婆婆', '首席陪審員給不纔但會人給分花不瞭分一大筆賣財財財財。嚮你要分花不瞭分一大筆賣財財財財瞭不纔但會人，這都是他的事兒，我們管不著。我們跑來傳你，你就該付我們小費，否則的話，那就彆怪我們對你不直言，我們不肯強迫你付分花不瞭分一大筆賣財財財財瞭。']
# ['action', ' 他們感嘆完，就動握把馬魯夫拽起來，要擅自搜身。']
# ['action', '馬魯夫不卻問道他們蠻不講理，一個個像小偷似的，不纔但會人彆的辦法，不肯將自己賴以生存的引褲子輔助用以賣給，用賣得的四分之一個銀幣還給他們，那大哥人不卻問道這個窮鬼簡直不纔但會人什麼油水可搾，馬上悻悻地停下來瞭。']
# ['action', '馬魯夫將他們打發停下來瞭之前，滿腹冤枉地頭在旁邊，雙握戈著皮膚上，愁眉不展。']
# ['action', '他以前什麼都不纔但會人瞭，整天就掙極少極少什麼分花不瞭分一大筆賣財財財財，今天連掙分花不瞭分一大筆賣財財財財的輔助用以都不纔但會人瞭，愈來愈是一無所有瞭，全傢人又有個難牽製的得心應握錶哥，之前的日子可怎麼過呀!']
# ['action', ' 他越不期望越內疚，真是自己從未是窮途末路瞭。']
# ['老婆婆', '起來!跟我們到首席陪審員那兒去，你錶哥把你告瞭!']
# ['老婆婆', '首席陪審員先是替我們進行談判完瞭，你們怎麼又來傳我?']
# ['老婆婆', '這迴你錶哥把你告到另一個首席陪審員那兒去瞭， 這是我們的首席陪審員傳你，快跟我們停下來吧!']
# ['action', ' 馬魯夫一不行，好像不由得痛破口大怒斥錶哥幾句，可是他又不纔但會人彆的辦法，不肯跟這兩個管事停下來。']
# ['老婆婆', '我們不是先是由首席陪審員勸解。和好瞭嗎? 你怎麼又到這兒來告我呢?']
# ['老婆婆', '你少?嗦! 上次那個首席陪審員雖然替我們作瞭進行談判，可是我們之間的爭執並不纔但會人剋服呀， 我跟你並不纔但會人和好!']
# ['action', ' 不行瞭得心應握錶哥的話，馬魯夫融得兩眼直冒金星。']
# ['老婆婆', '到底從未有一位首席陪審員替我們作瞭進行談判，我們從未和好瞭。']
# ['老婆婆', '你這個刁婦， 既然從未有首席陪審員給你們作瞭進行談判，而且你們兩口子從未和好瞭，為什麼你又到我這兒來告他，你這是什麼意指?']
# ['老婆婆', '可是他轉過頭去又打我瞭! 這能算和好嗎?']
# ['老婆婆', '你們兩口子在一個屋子住著，低頭居然抬頭不卻問道，有什麼剋服不瞭的話答道道題? 你認真前妻的今後一定免得受虐自己的錶哥，你認真錶哥的應善待自己的前妻，很難昧他。你們今後要盡力獨處。']
# ['action', ' 首席陪審員讓他們實情作瞭和好的意味著。']
# ['action', '馬魯夫憂慮那些管事於是又迴來麻煩，馬上把手上極少有的四分之一個銀幣給瞭他們。']
# ['action', '然後他無精打采地又離開引褲子的地方，無可奈何道自己應乾些什麼，他的意識顯然垮掉瞭。']
# ['窮人', '法官', '店老闆', '強盜']
# location:
# [(' ', 1), ('櫥窗', 1), ('法庭', 1), ('地頭', 1)]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-abb9b3ebe68b> in <module>
#      74                     if scene_character[i] == original_words[j]:
#      75                         scene_character[i] = scene_character[i].replace(scene_character[i], change_words[j])
# ---> 76         scene_location = s1.get_location()
#      77         scene_content = s1.get_content()
#      78         scene_time = time_cal.extract_time(new_text)
#
# /mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/info.py in get_location(self)
#     175                 for loc in self.scene_location:
#     176                     if loc[1] == num and (loc[0] in self.locations_distribution_dict):
# --> 177                         if self.locations_distribution_dict[loc[0]] > self.locations_distribution_dict[location]:
#     178                             location = loc[0]
#     179                 self.scene_location = location
#
# KeyError: ' '

# %%
import json

with open('test_output/text1_output.json') as f:
    d = json.load(f)

#script format
print('Story title: '+d.get('title'))
print()
for i in range(len(d.get('scene'))):
    print()
    print('Scene '+str(d.get('scene')[i].get('scene'))+'. 時 / '+d.get('scene')[i].get('time')+' 景 / '+d.get('scene')[i].get('location'))
    print()
    for j in range(len(d.get('scene')[i].get('contents'))):
        sentence = d.get('scene')[i].get('contents')[j]
        if ':' not in sentence:
            print('△ '+d.get('scene')[i].get('contents')[j])
        else :
            print(d.get('scene')[i].get('contents')[j])
        print()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-3e0063a2caab> in <module>
#       1 import json
#       2
# ----> 3 with open('test_output/text1_output.json') as f:
#       4     d = json.load(f)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_output/text1_output.json'
