# %%
import codecs
import json
import jieba
from os import listdir
from os.path import isfile, isdir, join
import sys

import scene_cal
import time_cal
import info
import rewrite
from hanziconv import HanziConv

sys.setrecursionlimit(1000000)

if __name__ == '__main__':
    print("Please enter the following story format:")
    print('{')
    print("title: XXXX")
    print("special person names: {Y1, Y2, Y3}")
    print("special location names: {Loc1, Loc2}")
    print("special object names: {O1, O2, O3}")
    print("story body:"+"\n"+"line1"+"\n"+"line2"+"\n"+"…."+"\n"+"linen.")
    print('}')
    
    print()
    path = input('File path:') # test_input/三隻小豬_input
    print()
    
    # read file
    jieba.set_dictionary('data/dict.txt.big')
    story = codecs.open(path, 'r', 'utf-8').read()
    story = story.replace('「', '“').replace('」', '”')
    title = story.split('\n')[0].split('title: ')[1].replace('\r', '')
    name = story.split('\n')[1].split('{')[1].split('}')[0].replace('}\r', '').split(', ')
    location = story.split('\n')[2].split('{')[1].split('}')[0].replace('}\r', '').split(', ')
    # object_name = story.split('\n')[3].split('{')[1].replace('}\r', '').split(', ')
    text = story.split('story body:')[1][2:].replace('\r', '')
    
    f_name = open("data/character_dict.txt", "a")
    f_loc = open("data/location_dict.txt", "a")
    for lines in name:
        f_name.writelines('\n'+lines)
    for lines in location:
        f_loc.writelines('\n'+lines)
    f_name.close()
    f_loc.close()
    
    print(title)
    print(name)
    print(location)
    print(text[0:500],'........')
    
    # build up the script
    cut_word = scene_cal.cuttest(text)
    temp_scene, temp_scene_num = scene_cal.split_scene(cut_word, text)
    scene, scene_num = scene_cal.check_whether_merge(temp_scene, temp_scene_num)
    all_characters = []
    scene_sum = []
    scene_idx = 1
    
    for i in range(scene_num):
        text_simple = HanziConv.toSimplified(scene[i])
        new_text, original_words, change_words = rewrite.rewrite(text_simple) # rewrite content
        new_text = HanziConv.toTraditional(new_text)
        
        s = info.Scene(scene[i])
        s1 = info.Scene(new_text)
        scene_character = s.get_character()
        print(scene_character)
        if len(scene_character)!=0:
            for i in range(len(scene_character)):
                for j in range(len(original_words)):
                    if scene_character[i] == original_words[j]:
                        scene_character[i] = scene_character[i].replace(scene_character[i], change_words[j])
        scene_location = s1.get_location()
        scene_content = s1.get_content()
        scene_time = time_cal.extract_time(new_text)

        scene_dict = {
            "scene": scene_idx,
            "location": scene_location,
            "time": scene_time,
            "character": scene_character,
            "contents": scene_content
        }
        all_characters += scene_character
        scene_sum.append(scene_dict)

        scene_idx += 1

    all_characters = list(set(all_characters))
    
    # write output file
    story_dict = {
        "title": title,
        "scenes": scene_num,
        "all_characters": all_characters,
        "scene": scene_sum
    }

    json_str = json.dumps(story_dict, indent=4, ensure_ascii=False)
    with open('test_output/' + title + '_output.json', 'w', encoding='utf-8') as json_file:
        json_file.write(json_str)
# Out:
# Please enter the following story format:
# {
# title: XXXX
# special person names: {Y1, Y2, Y3}
# special location names: {Loc1, Loc2}
# special object names: {O1, O2, O3}
# story body:
# line1
# line2
# ….
# linen.
# }
#
# File path:test_input/小紅帽_input
# Building prefix dict from /mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/data/dict.txt.big ...
# I0613 12:45:32.741537 139882218420032 __init__.py:111] Building prefix dict from /mnt/nas/yangyachi/ai_iterature_term_project/term_project3_v2/data/dict.txt.big ...
# Loading model from cache /tmp/jieba.ud829696f0cc60ca4174b11566884d37d.cache
# I0613 12:45:32.745721 139882218420032 __init__.py:131] Loading model from cache /tmp/jieba.ud829696f0cc60ca4174b11566884d37d.cache
# 小紅帽
# ['小紅帽', '狼', '奶奶', '獵人']
# ['森林', '奶奶家']
# 前有個可愛的小姑娘，誰見了都喜歡，但最喜歡她的是她的奶奶，簡直是她要什麼就給她什麼。一次，奶奶送給小姑娘一頂用絲絨做的小紅帽，戴在她的頭上正好合適。從此，姑娘再也不願意戴任何別的帽子，於是大家便叫她“小紅帽”。
# 一天，媽媽對小紅帽說：“來，小紅帽，這裡有一塊蛋糕和一瓶葡萄酒，快給奶奶送去，奶奶生病了，身子很虛弱，吃了這些就會好一些的。趁著現在天還沒有熱，趕緊動身吧。在路上要好好走，不要跑，也不要離開大路，否則你會摔跤的，那樣奶奶就什麼也吃不上了。到奶奶家的時候，別忘了說『早上好』，也不要一進屋就東瞧西瞅。”
# “我會小心的。”小紅帽對媽媽說，並且還和媽媽拉手作保證。
# 奶奶住在村子外面的森林裡，離小紅帽家有很長一段路。小紅帽剛走進森林就碰到了一條狼。小紅帽不知道狼是壞傢伙，所以一點也不怕它。
# “你好，小紅帽，”狼說。
# “謝謝你，狼先生。”
# “小紅帽，這麼早要到哪裡去呀？”
# “我要到奶奶家去。”
# “你那圍裙下面有什麼呀？”
# “蛋糕和葡萄酒。昨天我們家烤了一些蛋糕，可憐的奶奶生了病，要吃一些好東西才能恢復過來。”
# “你奶奶住在哪裡呀，小紅帽？”
# “進了林子還有一段路呢。她的房子就在三棵大橡樹下 ........
# Loading model cost 0.777 seconds.
# I0613 12:45:33.521796 139882218420032 __init__.py:163] Loading model cost 0.777 seconds.
# Prefix dict has been built succesfully.
# I0613 12:45:33.522596 139882218420032 __init__.py:164] Prefix dict has been built succesfully.
# #####scene
# 前有個可愛的小姑娘，誰見了都喜歡，但最喜歡她的是她的奶奶，簡直是她要什麼就給她什麼。一次，奶奶送給小姑娘一頂用絲絨做的小紅帽，戴在她的頭上正好合適。從此，姑娘再也不願意戴任何別的帽子，於是大家便叫她“小紅帽”。
# #####scene
# ['前有個可愛的小姑娘，誰見了都喜歡，但最喜歡她的是她的奶奶，簡直是她要什麼就給她什麼。一次，奶奶送給小姑娘一頂用絲絨做的小紅帽，戴在她的頭上正好合適。從此，姑娘再也不願意戴任何別的帽子，於是大家便叫她“小紅帽”。']
# [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'D-S', 'D', 'D', 'D', 'D-E', 'O-E']]
# =======dialogues=====
# ['小紅帽']
# =======dialogues=====
# 小紅帽
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('小紅帽', None, '老婆婆', 0.957460343837738)
# 老婆婆 : 小紅帽
# ['action', '前有個可愛的小姑娘，誰見了都喜歡，但最喜歡她的是她的奶奶，簡直是她要什麼就給她什麼。']
# ['action', '一次，奶奶送給小姑娘一頂用絲絨做的小紅帽，戴在她的頭上正好合適。']
# ['老婆婆', '小紅帽']
# #####scene
# 前有個天真的小農婦，誰方知瞭都愛好，但最愛好她的是她的阿姨，可笑是她要什麼就給她什麼。一次，阿姨送去小農婦一頂用絲絨做到的小紅帽，戴著著在她的手拿正好適閤。從此，農婦再也不願意戴著著任何彆的外衣，於是大傢立刻叫她“小紅帽”。
# #####scene
# ['前有個天真的小農婦，誰方知瞭都愛好，但最愛好她的是她的阿姨，可笑是她要什麼就給她什麼。一次，阿姨送去小農婦一頂用絲絨做到的小紅帽，戴著著在她的手拿正好適閤。從此，農婦再也不願意戴著著任何彆的外衣，於是大傢立刻叫她“小紅帽”。']
# [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'D-S', 'D', 'D', 'D', '
�道：“奶奶，快開門呀。我是小紅帽，給你送蛋糕來了。”但是她們既不說話，也不開門。這長著灰毛的傢伙圍著房子轉了兩三圈，最後跳上屋頂，打算等小紅帽在傍晚回家時偷偷跟在她的後面，趁天黑把她吃掉。可奶奶看穿了這傢伙的壞心思。她想起屋子前有一個大石頭槽子，便對小姑娘說：“小紅帽，把桶拿來。我昨天做了一些香腸，提些煮香腸的水去倒進石頭槽里。”小紅帽提了很多很多水，把那個大石頭槽子裝得滿滿的。香腸的氣味飄進了狼的鼻孔，它使勁地用鼻子聞呀聞，並且朝下張望著，到最後把脖子伸得太長了，身子開始往下滑。它從屋頂上滑了下來，正好落在大石槽中，淹死了。小紅帽高高興興地回了家，從此再也沒有誰傷害過她。']
# [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'O', 'O', 'O-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O-E', 'D-S', 'D', 'D', 'D', 'D', 'D-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D-E', 'O', 'O', 'O', 'O', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D-E', 'O', 'O', 'O', 'O', 'O', 'O', 'D-S', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D',  ...
# =======dialogues=====
# ['來，小紅帽，這裡有一塊蛋糕和一瓶葡萄酒，快給奶奶送去，奶奶生病了，身子很虛弱，吃了這些就會好一些的。趁著現在天還沒有熱，趕緊動身吧。在路上要好好走，不要跑，也不要離開大路，否則你會摔跤的，那樣奶奶就什麼也吃不上了。到奶奶家的時候，別忘了說『早上好』，也不要一進屋就東瞧西瞅。', '我會小心的。', '你好，小紅帽，謝謝你，狼先生。', '小紅帽，這麼早要到哪裡去呀？', '我要到奶奶家去。', '你那圍裙下面有什麼呀？', '蛋糕和葡萄酒。昨天我們家烤了一些蛋糕，可憐的奶奶生了病，要吃一些好東西才能恢復過來。', '你奶奶住在哪裡呀，小紅帽？', '進了林子還有一段路呢。她的房子就在三棵大橡樹下，低處圍著核桃樹籬笆。你一定知道的。', '這小東西細皮嫩肉的，味道肯定比那老太婆要好。我要講究一下策略，讓她倆都逃不出我的手心。', '小紅帽，你看周圍這些花多麼美麗啊！幹嗎不回頭看一看呢？還有這些小鳥，它們唱得多麼動聽啊！你大概根本沒有聽到吧？林子里的一切多麼美好啊，而你卻只管往前走，就像是去上學一樣。', '也許我該摘一把鮮花給奶奶，讓她高興高興。現在天色還早，我不會去遲的。', '是誰呀？', '是小紅帽。', '我給你送蛋糕和葡萄酒來了。快開門哪。', '你拉一下門栓就行了，我身上沒有力氣，起不來。', '天哪！平常我那麼喜歡來奶奶家，今天怎麼這樣害怕？', '早上好！', '哎，奶奶，你的耳朵怎麼這樣大呀？', '為了更好地聽你說話呀，乖乖。', '可是奶奶，你的眼睛怎麼這樣大呀？', '為了更清楚地看你呀，乖乖。', '奶奶，你的手怎麼這樣大呀？', '可以更好地抱著你呀。', '奶奶，你的嘴巴怎麼大得很嚇人呀？', '可以一口把你吃掉呀！', '這老太太鼾打得好響啊！我要進去看看她是不是出什麼事了。', '你這老壞蛋，我找了你這麼久，真沒想到在這裡找到你！', '真把我嚇壞了！狼肚子里黑漆漆的。', '要是媽媽不允許，我一輩子也不獨自離開大路，跑進森林了。', '你好', '那麼，我們把門關緊，不讓它進來。', '奶奶，快開門呀。我是小紅帽，給你送蛋糕來了。', '小紅帽，把桶拿來。我昨天做了一些香腸，提些煮香腸的水去倒進石頭槽里。']
# =======dialogues=====
# 來，小紅帽，這裡有一塊蛋糕和一瓶葡萄酒，快給奶奶送去，奶奶生病了，身子很虛弱，吃了這些就會好一些的。趁著現在天還沒有熱，趕緊動身吧。在路上要好好走，不要跑，也不要離開大路，否則你會摔跤的，那樣奶奶就什麼也吃不上了。到奶奶家的時候，別忘了說『早上好』，也不要一進屋就東瞧西瞅。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('來，小紅帽，這裡有一塊蛋糕和一瓶葡萄酒，快給奶奶送去，奶奶生病了，身子很虛弱，吃了這些就會好一些的。趁著現在天還沒有熱，趕緊動身吧。在路上要好好走，不要跑，也不要離開大路，否則你會摔跤的，那樣奶奶就什麼也吃不上了。到奶奶家的時候，別忘了說『早上好』，也不要一進屋就東瞧西瞅。', None, '媽媽', 1.0)
# 媽媽 : 來，小紅帽，這裡有一塊蛋糕和一瓶葡萄酒，快給奶奶送去，奶奶生病了，身子很虛弱，吃了這些就會好一些的。趁著現在天還沒有熱，趕緊動身吧。在路上要好好走，不要跑，也不要離開大路，否則你會摔跤的，那樣奶奶就什麼也吃不上了。到奶奶家的時候，別忘了說『早上好』，也不要一進屋就東瞧西瞅。
# 我會小心的。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('我會小心的。', None, '小紅帽', 1.0)
# 小紅帽 : 我會小心的。
# 你好，小紅帽，謝謝你，狼先生。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你好，小紅帽，謝謝你，狼先生。', None, '老婆婆', 0.9888566136360168)
# 老婆婆 : 你好，小紅帽，謝謝你，狼先生。
# 小紅帽，這麼早要到哪裡去呀？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('小紅帽，這麼早要到哪裡去呀？', None, '狼', 1.0)
# 狼 : 小紅帽，這麼早要到哪裡去呀？
# 我要到奶奶家去。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('我要到奶奶家去。', None, '小紅帽', 1.0)
# 小紅帽 : 我要到奶奶家去。
# 你那圍裙下面有什麼呀？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你那圍裙下面有什麼呀？', None, '狼', 1.0)
# 狼 : 你那圍裙下面有什麼呀？
# 蛋糕和葡萄酒。昨天我們家烤了一些蛋糕，可憐的奶奶生了病，要吃一些好東西才能恢復過來。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('蛋糕和葡萄酒。昨天我們家烤了一些蛋糕，可憐的奶奶生了病，要吃一些好東西才能恢復過來。', None, '小紅帽', 1.0)
# 小紅帽 : 蛋糕和葡萄酒。昨天我們家烤了一些蛋糕，可憐的奶奶生了病，要吃一些好東西才能恢復過來。
# 你奶奶住在哪裡呀，小紅帽？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你奶奶住在哪裡呀，小紅帽？', None, '狼', 1.0)
# 狼 : 你奶奶住在哪裡呀，小紅帽？
# 進了林子還有一段路呢。她的房子就在三棵大橡樹下，低處圍著核桃樹籬笆。你一定知道的。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('進了林子還有一段路呢。她的房子就在三棵大橡樹下，低處圍著核桃樹籬笆。你一定知道的。', None, '小紅帽', 1.0)
# 小紅帽 : 進了林子還有一段路呢。她的房子就在三棵大橡樹下，低處圍著核桃樹籬笆。你一定知道的。
# 這小東西細皮嫩肉的，味道肯定比那老太婆要好。我要講究一下策略，讓她倆都逃不出我的手心。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('這小東西細皮嫩肉的，味道肯定比那老太婆要好。我要講究一下策略，讓她倆都逃不出我的手心。', None, '老婆婆', 0.9796402454376221)
# 老婆婆 : 這小東西細皮嫩肉的，味道肯定比那老太婆要好。我要講究一下策略，讓她倆都逃不出我的手心。
# 小紅帽，你看周圍這些花多麼美麗啊！幹嗎不回頭看一看呢？還有這些小鳥，它們唱得多麼動聽啊！你大概根本沒有聽到吧？林子里的一切多麼美好啊，而你卻只管往前走，就像是去上學一樣。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('小紅帽，你看周圍這些花多麼美麗啊！幹嗎不回頭看一看呢？還有這些小鳥，它們唱得多麼動聽啊！你大概根本沒有聽到吧？林子里的一切多麼美好啊，而你卻只管往前走，就像是去上學一樣。', None, '狼', 1.0)
# 狼 : 小紅帽，你看周圍這些花多麼美麗啊！幹嗎不回頭看一看呢？還有這些小鳥，它們唱得多麼動聽啊！你大概根本沒有聽到吧？林子里的一切多麼美好啊，而你卻只管往前走，就像是去上學一樣。
# 也許我該摘一把鮮花給奶奶，讓她高興高興。現在天色還早，我不會去遲的。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('也許我該摘一把鮮花給奶奶，讓她高興高興。現在天色還早，我不會去遲的。', None, '小紅帽', 1.0)
# 小紅帽 : 也許我該摘一把鮮花給奶奶，讓她高興高興。現在天色還早，我不會去遲的。
# 是誰呀？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('是誰呀？', None, '奶奶', 1.0)
# 奶奶 : 是誰呀？
# 是小紅帽。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('是小紅帽。', None, '老婆婆', 0.9718892574310303)
# 老婆婆 : 是小紅帽。
# 我給你送蛋糕和葡萄酒來了。快開門哪。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('我給你送蛋糕和葡萄酒來了。快開門哪。', None, '老婆婆', 0.9118659496307373)
# 老婆婆 : 我給你送蛋糕和葡萄酒來了。快開門哪。
# 你拉一下門栓就行了，我身上沒有力氣，起不來。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你拉一下門栓就行了，我身上沒有力氣，起不來。', None, '奶奶', 1.0)
# 奶奶 : 你拉一下門栓就行了，我身上沒有力氣，起不來。
# 天哪！平常我那麼喜歡來奶奶家，今天怎麼這樣害怕？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('天哪！平常我那麼喜歡來奶奶家，今天怎麼這樣害怕？', None, '老婆婆', 0.9681136608123779)
# 老婆婆 : 天哪！平常我那麼喜歡來奶奶家，今天怎麼這樣害怕？
# 早上好！
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('早上好！', None, '小紅帽', 1.0)
# 小紅帽 : 早上好！
# 哎，奶奶，你的耳朵怎麼這樣大呀？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('哎，奶奶，你的耳朵怎麼這樣大呀？', None, '小紅帽', 1.0)
# 小紅帽 : 哎，奶奶，你的耳朵怎麼這樣大呀？
# 為了更好地聽你說話呀，乖乖。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('為了更好地聽你說話呀，乖乖。', None, '狼', 1.0)
# 狼 : 為了更好地聽你說話呀，乖乖。
# 可是奶奶，你的眼睛怎麼這樣大呀？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('可是奶奶，你的眼睛怎麼這樣大呀？', None, '小紅帽', 1.0)
# 小紅帽 : 可是奶奶，你的眼睛怎麼這樣大呀？
# 為了更清楚地看你呀，乖乖。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('為了更清楚地看你呀，乖乖。', None, '狼', 1.0)
# 狼 : 為了更清楚地看你呀，乖乖。
# 奶奶，你的手怎麼這樣大呀？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('奶奶，你的手怎麼這樣大呀？', None, '小紅帽', 1.0)
# 小紅帽 : 奶奶，你的手怎麼這樣大呀？
# 可以更好地抱著你呀。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('可以更好地抱著你呀。', None, '狼', 1.0)
# 狼 : 可以更好地抱著你呀。
# 奶奶，你的嘴巴怎麼大得很嚇人呀？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('奶奶，你的嘴巴怎麼大得很嚇人呀？', None, '小紅帽', 0.9999990463256836)
# 小紅帽 : 奶奶，你的嘴巴怎麼大得很嚇人呀？
# 可以一口把你吃掉呀！
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('可以一口把你吃掉呀！', None, '狼', 1.0)
# 狼 : 可以一口把你吃掉呀！
# 這老太太鼾打得好響啊！我要進去看看她是不是出什麼事了。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('這老太太鼾打得好響啊！我要進去看看她是不是出什麼事了。', None, '獵人', 1.0)
# 獵人 : 這老太太鼾打得好響啊！我要進去看看她是不是出什麼事了。
# 你這老壞蛋，我找了你這麼久，真沒想到在這裡找到你！
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你這老壞蛋，我找了你這麼久，真沒想到在這裡找到你！', None, '獵人', 1.0)
# 獵人 : 你這老壞蛋，我找了你這麼久，真沒想到在這裡找到你！
# 真把我嚇壞了！狼肚子里黑漆漆的。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('真把我嚇壞了！狼肚子里黑漆漆的。', None, '小紅帽', 1.0)
# 小紅帽 : 真把我嚇壞了！狼肚子里黑漆漆的。
# 要是媽媽不允許，我一輩子也不獨自離開大路，跑進森林了。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('要是媽媽不允許，我一輩子也不獨自離開大路，跑進森林了。', None, '老婆婆', 0.9614056348800659)
# 老婆婆 : 要是媽媽不允許，我一輩子也不獨自離開大路，跑進森林了。
# 你好
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你好', None, '老婆婆', 0.5566310882568359)
# 媽媽 : 你好
# 那麼，我們把門關緊，不讓它進來。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# ...
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('爺爺，你的揮怎麼這樣大呀？', None, '老婆婆', 0.8897899389266968)
# 小紅帽 : 爺爺，你的揮怎麼這樣大呀？
# 可以不夠好地背著著你呀。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('可以不夠好地背著著你呀。', None, '老婆婆', 0.9870753884315491)
# 老婆婆 : 可以不夠好地背著著你呀。
# 爺爺，你的屁股怎麼大得很有趣呀？
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('爺爺，你的屁股怎麼大得很有趣呀？', None, '老婆婆', 0.9378948211669922)
# 老婆婆 : 爺爺，你的屁股怎麼大得很有趣呀？
# 可以一口把你吃完飽飯飯掉呀！
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('可以一口把你吃完飽飯飯掉呀！', None, '老婆婆', 0.9610781669616699)
# 老婆婆 : 可以一口把你吃完飽飯飯掉呀！
# 這老太太鼾打得好放啊！我要上去希望希望她究竟齣什麼兩件事瞭。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('這老太太鼾打得好放啊！我要上去希望希望她究竟齣什麼兩件事瞭。', None, '老婆婆', 0.9911191463470459)
# 老婆婆 : 這老太太鼾打得好放啊！我要上去希望希望她究竟齣什麼兩件事瞭。
# 你這老壞蛋，我找瞭你這麼久，真沒不希望要到在這裏找尋你！
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你這老壞蛋，我找瞭你這麼久，真沒不希望要到在這裏找尋你！', None, '老婆婆', 0.9409372210502625)
# 老婆婆 : 你這老壞蛋，我找瞭你這麼久，真沒不希望要到在這裏找尋你！
# 真把我希望到瞭！老虎希望到裏黑漆漆的。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('真把我希望到瞭！老虎希望到裏黑漆漆的。', None, '老婆婆', 0.912229597568512)
# 老婆婆 : 真把我希望到瞭！老虎希望到裏黑漆漆的。
# 要是姐姐不而無須，我一輩子也不獨自歸來到南大三四門，衝刺進原始雨林瞭。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('要是姐姐不而無須，我一輩子也不獨自歸來到南大三四門，衝刺進原始雨林瞭。', None, '老婆婆', 0.9806174039840698)
# 老婆婆 : 要是姐姐不而無須，我一輩子也不獨自歸來到南大三四門，衝刺進原始雨林瞭。
# 你好
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('你好', None, '老婆婆', 0.5566310882568359)
# 小紅帽 : 你好
# 那麼，我們把三四門關緊，竟然它進來。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('那麼，我們把三四門關緊，竟然它進來。', None, '老婆婆', 0.9113378524780273)
# 老婆婆 : 那麼，我們把三四門關緊，竟然它進來。
# 爺爺，快後三四門呀。我是小紅帽，給你還給糖果來瞭。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('爺爺，快後三四門呀。我是小紅帽，給你還給糖果來瞭。', None, '老婆婆', 0.9925995469093323)
# 老婆婆 : 爺爺，快後三四門呀。我是小紅帽，給你還給糖果來瞭。
# 小紅帽，把桶常以。我昨天來作瞭一些牛排，托些烹煮牛排的浮去推倒進沙子頂部裏。
# loading DialogueClassification/training_data_ch.char_to_idx
# loading DialogueClassification/training_data_ch.word_to_idx
# loading DialogueClassification/training_data_ch.tag_to_idx
# cnn(
#   (embed): embed(
#     (char_embed): embed_cnn(
#       (embed): Embedding(1536, 50, padding_idx=0)
#       (conv): ModuleList(
#         (0): Conv2d(1, 50, kernel_size=(3, 50), stride=(1, 1))
#       )
#       (dropout): Dropout(p=0.5)
#       (fc): Linear(in_features=50, out_features=150, bias=True)
#     )
#     (word_embed): Embedding(794, 150, padding_idx=0)
#   )
#   (conv): ModuleList(
#     (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#     (1): Conv2d(1, 100, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 100, kernel_size=(4, 300), stride=(1, 1))
#   )
#   (dropout): Dropout(p=0.5)
#   (fc): Linear(in_features=300, out_features=156, bias=True)
#   (softmax): LogSoftmax()
# )
# loading DialogueClassification/save_model_ch/model.epoch3000
# saved model: epoch = 3000, loss = 0.011889
# ('小紅帽，把桶常以。我昨天來作瞭一些牛排，托些烹煮牛排的浮去推倒進沙子頂部裏。', None, '老婆婆', 0.9961053729057312)
# 老婆婆 : 小紅帽，把桶常以。我昨天來作瞭一些牛排，托些烹煮牛排的浮去推倒進沙子頂部裏。
# ['老婆婆', '來，小紅帽，這裏有石闆糖果和一瓶白香檳，快給爺爺還給去，爺爺生病瞭，雙腳很無法控製，吃完飽飯飯瞭這些就亦則會好一些的。趁著今日天還不會熱，來不及歸途吧。在路過要用心停都已，不不希望要衝刺，也不不希望要歸來到南大三四門，否則你亦則會拳擊的，那樣爺爺就什麼也吃完飽飯飯不上瞭。到爺爺傢的時候，彆忘瞭真是『要到上好』，也不不希望要一上樓就西麵瞧西麵瞅。']
# ['小紅帽', '我亦則會小心翼翼的。']
# ['action', '小紅帽對姐姐真是，並且還和姐姐努揮作保障。']
# ['action', '爺爺住在鎮子角落的原始雨林裏，離小紅帽傢有很較寬一段路。']
# ['action', '小紅帽正要正要停都已進原始雨林就鑽進瞭一條老虎。']
# ['action', '小紅帽不得知他老虎是壞白癡，所以一點也不怕它。']
# ['action', '老虎真是。']
# ['老婆婆', '你好，小紅帽，再見你，老虎先生。']
# ['老婆婆', '小紅帽，這麼要到要到哪裏去呀？']
# ['老婆婆', '我要到爺爺傢去。']
# ['老婆婆', '你那領帶下麵有什麼呀？']
# ['老婆婆', '糖果和白香檳。昨天我們傢醬汁瞭一些糖果，心裏的爺爺生瞭病，要吃完飽飯飯一些好西麵西麵纔能恢復過來。']
# ['老婆婆', '你爺爺住在哪裏呀，小紅帽？']
# ['老婆婆', '進瞭林子還有一段路呢。她的公寓就在三棵大紅木下，較高不遠處牆外核桃樹圍牆。你一定得知他的。']
# ['action', '小紅帽真是。']
# ['老婆婆', '這小西麵西麵細皮嫩肉的，原味無疑比那老太婆要好。我要講求一下策略，讓她倆都逃不齣我的輕輕。']
# ['老婆婆', '小紅帽，你看區域內這些花多麼優雅啊！乾嗎不上去看一看呢？還有這些兔子，它們唱齣得多麼歌聲啊！你大概確實不會哭得吧？林子裏的一切多麼美好啊，而你卻隻管往前停都已，就或許去離傢一樣。']
# ['老婆婆', '或許我該摘一把箱點給爺爺，讓她後悔後悔。今日時分還要到，我不亦則會去遲的。']
# ['action', '她於是歸來到南大三四門，停都已進林子去採花。']
# ['action', '她每採下一朵花，總答道道道道上麵還有不夠優雅的花瓣，日後又嚮前停都已去，結果多年來停下歸來到瞭林子深不遠處。']
# ['action', '就在此時，老虎卻同樣衝刺到爺爺傢，打碎瞭打碎三四門。']
# ['奶奶', '是誰呀？']
# ['老婆婆', '是小紅帽。']
# ['老婆婆', '我給你還給糖果和白香檳來瞭。快後三四門哪。']
# ['老婆婆', '你努一下三四門栓就行瞭，我頭上不會拼命，起不來。']
# ['action', '老虎答道道道，爺爺低頭真是，老虎正要正要努起三四門栓，那三四門就開瞭。']
# ['action', '老虎二話沒真是就衝齣爺爺的墊前，把爺爺吞進瞭希望到。']
# ['action', '然後她脫下上爺爺的衣物，穿上她的帽，胳膊在墊上，還努上瞭簾子。']
# ['action', '可這時小紅帽還在衝刺來衝刺去地採花。']
# ['action', '直到采瞭許多許多，她都拿根本無法啦，她纔不希望要起爺爺，再一上路去爺爺傢。']
# ['action', '不明白爺爺傢的屋裏三四門敞開著，她不已很好奇。']
# ['老婆婆', '天哪！平時我那麼喜好來爺爺傢，時至今日怎麼這樣害怕？']
# ['小紅帽', '要到上好！']
# ['action', '，可是不會哭得答道道道。']
# ['action', '她停下歸來到墊前努開簾子，隻見爺爺胳膊在墊上，帽努得較高較高的，把微笑都遮擋瞭，看起來相當好奇。']
# ['老婆婆', '哎，爺爺，你的鳥嘴唇怎麼這樣大呀？']
# ['老婆婆', '為瞭不夠好地哭你感嘆話呀，乖乖。']
# ['老婆婆', '可是爺爺，你的額頭怎麼這樣大呀？']
# ['action', '她真是，小紅帽又答道。']
# ['老婆婆', '為瞭不夠明確地看你呀，乖乖。']
# ['小紅帽', '爺爺，你的揮怎麼這樣大呀？']
# ['老婆婆', '可以不夠好地背著著你呀。']
# ['老婆婆', '爺爺，你的屁股怎麼大得很有趣呀？']
# ['老婆婆', '可以一口把你吃完飽飯飯掉呀！']
# ['action', '老虎正要正要把話感嘆完，就從墊上起跳起起來，把小紅帽吞進瞭希望到，老虎滿足瞭食慾在此之後日後再一胳膊到墊上喝浮，而且鼾聲震天。']
# ['老婆婆', '這老太太鼾打得好放啊！我要上去希望希望她究竟齣什麼兩件事瞭。']
# ['action', '同伴進瞭屋裏，歸來到墊前時卻推斷齣胳膊在那裏的發覺老虎。']
# ['老婆婆', '你這老壞蛋，我找瞭你這麼久，真沒不希望要到在這裏找尋你！']
# ['action', '他感嘆。']
# ['action', '他正將要嚮老虎打傷，接二連三又不希望要到，這老虎很不太可能把爺爺吞進瞭希望到，爺爺或許還活著。']
# ['action', '同伴就不會打傷，而是操起一把捏，動揮把呼呼大整天的老虎的希望到扯瞭開來。']
# ['action', '他正要正要扯瞭兩下，就不明白瞭藍色的小帽。']
# ['老婆婆', '真把我希望到瞭！老虎希望到裏黑漆漆的。']
# ['action', '接著，爺爺也活著齣來瞭，隻是卻是喘不過煉來。']
# ['action', '小紅帽來不及衝刺去隔壁幾塊大沙子，扔掉老虎的希望到。']
# ['action', '老虎奄奄一息在此之後不希望要逃停都已，可是那些沙子太重瞭，它正要正要東站起來就滑落到在地，摔推倒瞭。']
# ['action', '三個人後悔極瞭。']
# ['action', '同伴剝下老虎皮，偷偷去瞭；']
# ['action', '爺爺吃完飽飯飯瞭小紅帽造就的糖果和白香檳，人格好多瞭；']
# ['老婆婆', '要是姐姐不而無須，我一輩子也不獨自歸來到南大三四門，衝刺進原始雨林瞭。']
# ['action', '人們還感嘆，小紅帽在此之後又有一次把糖果還給給爺爺，而且在路過又有一隻老虎跟她搭話，不希望要騙她歸來到南大三四門。']
# ['action', '可小紅帽這次進一步托高瞭托防，頭也不歸來地嚮前停都已。']
# ['小紅帽', '你好']
# ['action', '她得知爺爺她鑽進瞭老虎，那白癡鳥嘴上雖然對她感嘆，額頭裏卻露著自是紅光，要不是在南大三四門過，它準把她給吃完飽飯飯瞭。']
# ['老婆婆', '那麼，我們把三四門關緊，竟然它進來。']
# ['老婆婆', '爺爺，快後三四門呀。我是小紅帽，給你還給糖果來瞭。']
# ['action', '但是她們既不感嘆話，也不後三四門。']
# ['action', '這較寬著灰毛的白癡牆外公寓轉瞭兩三圈，之前起跳起上屋裏頂，正要等小紅帽在早上偷偷時偷偷跟在她的上麵，趁天黑把她吃完飽飯飯掉。']
# ['action', '可爺爺看脫下瞭這白癡的壞工夫。']
# ['老婆婆', '小紅帽，把桶常以。我昨天來作瞭一些牛排，托些烹煮牛排的浮去推倒進沙子頂部裏。']
# ['action', '小紅帽托瞭很多很多浮，把那個大沙子頂部子箱得滿滿的。']
# ['action', '牛排的煉味飄進瞭老虎的上頜，它使勁地用嘴巴嘗呀嘗，並且朝下張望著，到之前把腿伸得太較寬瞭，雙腳開始往飆升。']
# ['action', '它從屋裏頂上滑瞭都已，正好落在大石頂部當中，獲救瞭。']
# ['action', '小紅帽高後悔興地歸來瞭傢，從此再也不會誰人身過她。']
# ['小姑娘', '獵人', '小紅帽', '狼', '媽媽']
# location:
# []
# 家

# %%
import json

with open('test_output/小紅帽_output.json') as f:
    d = json.load(f)

#script format
print('Story title: '+d.get('title'))
print()
for i in range(len(d.get('scene'))):
    print()
    print('Scene '+str(d.get('scene')[i].get('scene'))+'. 時 / '+d.get('scene')[i].get('time')+' 景 / '+d.get('scene')[i].get('location'))
    print()
    for j in range(len(d.get('scene')[i].get('contents'))):
        sentence = d.get('scene')[i].get('contents')[j]
        if ':' not in sentence:
            print('△ '+d.get('scene')[i].get('contents')[j])
        else :
            print(d.get('scene')[i].get('contents')[j])
        print()
# Out:
# Story title: 小紅帽
#
#
# Scene 1. 時 / 白天 景 / 家
#
# △ 前有個天真的小農婦，誰方知瞭都愛好，但最愛好她的是她的阿姨，可笑是她要什麼就給她什麼。
#
# △ 一次，阿姨送去小農婦一頂用絲絨做到的小紅帽，戴著著在她的手拿正好適閤。
#
# 老婆婆 : 小紅帽
#
#
# Scene 2. 時 / 白天 景 / 家
#
# 老婆婆 : 來，小紅帽，這裏有石闆糖果和一瓶白香檳，快給爺爺還給去，爺爺生病瞭，雙腳很無法控製，吃完飽飯飯瞭這些就亦則會好一些的。趁著今日天還不會熱，來不及歸途吧。在路過要用心停都已，不不希望要衝刺，也不不希望要歸來到南大三四門，否則你亦則會拳擊的，那樣爺爺就什麼也吃完飽飯飯不上瞭。到爺爺傢的時候，彆忘瞭真是『要到上好』，也不不希望要一上樓就西麵瞧西麵瞅。
#
# 小紅帽 : 我亦則會小心翼翼的。
#
# △ 小紅帽對姐姐真是，並且還和姐姐努揮作保障。
#
# △ 爺爺住在鎮子角落的原始雨林裏，離小紅帽傢有很較寬一段路。
#
# △ 小紅帽正要正要停都已進原始雨林就鑽進瞭一條老虎。
#
# △ 小紅帽不得知他老虎是壞白癡，所以一點也不怕它。
#
# △ 老虎真是。
#
# 老婆婆 : 你好，小紅帽，再見你，老虎先生。
#
# 老婆婆 : 小紅帽，這麼要到要到哪裏去呀？
#
# 老婆婆 : 我要到爺爺傢去。
#
# 老婆婆 : 你那領帶下麵有什麼呀？
#
# 老婆婆 : 糖果和白香檳。昨天我們傢醬汁瞭一些糖果，心裏的爺爺生瞭病，要吃完飽飯飯一些好西麵西麵纔能恢復過來。
#
# 老婆婆 : 你爺爺住在哪裏呀，小紅帽？
#
# 老婆婆 : 進瞭林子還有一段路呢。她的公寓就在三棵大紅木下，較高不遠處牆外核桃樹圍牆。你一定得知他的。
#
# △ 小紅帽真是。
#
# 老婆婆 : 這小西麵西麵細皮嫩肉的，原味無疑比那老太婆要好。我要講求一下策略，讓她倆都逃不齣我的輕輕。
#
# 老婆婆 : 小紅帽，你看區域內這些花多麼優雅啊！乾嗎不上去看一看呢？還有這些兔子，它們唱齣得多麼歌聲啊！你大概確實不會哭得吧？林子裏的一切多麼美好啊，而你卻隻管往前停都已，就或許去離傢一樣。
#
# 老婆婆 : 或許我該摘一把箱點給爺爺，讓她後悔後悔。今日時分還要到，我不亦則會去遲的。
#
# △ 她於是歸來到南大三四門，停都已進林子去採花。
#
# △ 她每採下一朵花，總答道道道道上麵還有不夠優雅的花瓣，日後又嚮前停都已去，結果多年來停下歸來到瞭林子深不遠處。
#
# △ 就在此時，老虎卻同樣衝刺到爺爺傢，打碎瞭打碎三四門。
#
# 奶奶 : 是誰呀？
#
# 老婆婆 : 是小紅帽。
#
# 老婆婆 : 我給你還給糖果和白香檳來瞭。快後三四門哪。
#
# 老婆婆 : 你努一下三四門栓就行瞭，我頭上不會拼命，起不來。
#
# △ 老虎答道道道，爺爺低頭真是，老虎正要正要努起三四門栓，那三四門就開瞭。
#
# △ 老虎二話沒真是就衝齣爺爺的墊前，把爺爺吞進瞭希望到。
#
# △ 然後她脫下上爺爺的衣物，穿上她的帽，胳膊在墊上，還努上瞭簾子。
#
# △ 可這時小紅帽還在衝刺來衝刺去地採花。
#
# △ 直到采瞭許多許多，她都拿根本無法啦，她纔不希望要起爺爺，再一上路去爺爺傢。
#
# △ 不明白爺爺傢的屋裏三四門敞開著，她不已很好奇。
#
# 老婆婆 : 天哪！平時我那麼喜好來爺爺傢，時至今日怎麼這樣害怕？
#
# 小紅帽 : 要到上好！
#
# △ ，可是不會哭得答道道道。
#
# △ 她停下歸來到墊前努開簾子，隻見爺爺胳膊在墊上，帽努得較高較高的，把微笑都遮擋瞭，看起來相當好奇。
#
# 老婆婆 : 哎，爺爺，你的鳥嘴唇怎麼這樣大呀？
#
# 老婆婆 : 為瞭不夠好地哭你感嘆話呀，乖乖。
#
# 老婆婆 : 可是爺爺，你的額頭怎麼這樣大呀？
#
# △ 她真是，小紅帽又答道。
#
# 老婆婆 : 為瞭不夠明確地看你呀，乖乖。
#
# 小紅帽 : 爺爺，你的揮怎麼這樣大呀？
#
# 老婆婆 : 可以不夠好地背著著你呀。
#
# 老婆婆 : 爺爺，你的屁股怎麼大得很有趣呀？
#
# 老婆婆 : 可以一口把你吃完飽飯飯掉呀！
#
# △ 老虎正要正要把話感嘆完，就從墊上起跳起起來，把小紅帽吞進瞭希望到，老虎滿足瞭食慾在此之後日後再一胳膊到墊上喝浮，而且鼾聲震天。
#
# 老婆婆 : 這老太太鼾打得好放啊！我要上去希望希望她究竟齣什麼兩件事瞭。
#
# △ 同伴進瞭屋裏，歸來到墊前時卻推斷齣胳膊在那裏的發覺老虎。
#
# 老婆婆 : 你這老壞蛋，我找瞭你這麼久，真沒不希望要到在這裏找尋你！
#
# △ 他感嘆。
#
# △ 他正將要嚮老虎打傷，接二連三又不希望要到，這老虎很不太可能把爺爺吞進瞭希望到，爺爺或許還活著。
#
# △ 同伴就不會打傷，而是操起一把捏，動揮把呼呼大整天的老虎的希望到扯瞭開來。
#
# △ 他正要正要扯瞭兩下，就不明白瞭藍色的小帽。
#
# 老婆婆 : 真把我希望到瞭！老虎希望到裏黑漆漆的。
#
# △ 接著，爺爺也活著齣來瞭，隻是卻是喘不過煉來。
#
# △ 小紅帽來不及衝刺去隔壁幾塊大沙子，扔掉老虎的希望到。
#
# △ 老虎奄奄一息在此之後不希望要逃停都已，可是那些沙子太重瞭，它正要正要東站起來就滑落到在地，摔推倒瞭。
#
# △ 三個人後悔極瞭。
#
# △ 同伴剝下老虎皮，偷偷去瞭；
#
# △ 爺爺吃完飽飯飯瞭小紅帽造就的糖果和白香檳，人格好多瞭；
#
# 老婆婆 : 要是姐姐不而無須，我一輩子也不獨自歸來到南大三四門，衝刺進原始雨林瞭。
#
# △ 人們還感嘆，小紅帽在此之後又有一次把糖果還給給爺爺，而且在路過又有一隻老虎跟她搭話，不希望要騙她歸來到南大三四門。
#
# △ 可小紅帽這次進一步托高瞭托防，頭也不歸來地嚮前停都已。
#
# 小紅帽 : 你好
#
# △ 她得知爺爺她鑽進瞭老虎，那白癡鳥嘴上雖然對她感嘆，額頭裏卻露著自是紅光，要不是在南大三四門過，它準把她給吃完飽飯飯瞭。
#
# 老婆婆 : 那麼，我們把三四門關緊，竟然它進來。
#
# 老婆婆 : 爺爺，快後三四門呀。我是小紅帽，給你還給糖果來瞭。
#
# △ 但是她們既不感嘆話，也不後三四門。
#
# △ 這較寬著灰毛的白癡牆外公寓轉瞭兩三圈，之前起跳起上屋裏頂，正要等小紅帽在早上偷偷時偷偷跟在她的上麵，趁天黑把她吃完飽飯飯掉。
#
# △ 可爺爺看脫下瞭這白癡的壞工夫。
#
# 老婆婆 : 小紅帽，把桶常以。我昨天來作瞭一些牛排，托些烹煮牛排的浮去推倒進沙子頂部裏。
#
# △ 小紅帽托瞭很多很多浮，把那個大沙子頂部子箱得滿滿的。
#
# △ 牛排的煉味飄進瞭老虎的上頜，它使勁地用嘴巴嘗呀嘗，並且朝下張望著，到之前把腿伸得太較寬瞭，雙腳開始往飆升。
#
# △ 它從屋裏頂上滑瞭都已，正好落在大石頂部當中，獲救瞭。
#
# △ 小紅帽高後悔興地歸來瞭傢，從此再也不會誰人身過她。
